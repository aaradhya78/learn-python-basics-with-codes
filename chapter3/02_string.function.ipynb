# %%
# len()function
name= "aaradhya"
print(len(name))
# Out:
# 8

# %%
# string.endswith()  &   string.startswith()    (string can be anything example- name.endswith )

name = "aaradhya"
print(name.endswith("hya"))
print(name.startswith("aa"))

# output will be true or a false
# Out:
# True
# True

# %%
# string.count 

name="aaradhya"
print(name.count(""))
# Out:
# 0

# %%
# string.capitalize

name="aaradhya"
print(name.capitalize())
# Out:
# Aaradhya

# %%
# string.find(word)

name = "aaradhya sharma"
print(name.find("sharma"))
# Out:
# 9

# %%
# string.replace("old word" , "new word")

name= "wind fire water gun"
print(name.replace("gun","air"))
print(name.replace("wind","boom"))
# Out:
# wind fire water air
# boom fire water gun
