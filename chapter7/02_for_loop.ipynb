# %%
for i in range(4):
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
for i in range(0,101,4):
    print(i)
# Out:
# 0
# 4
# 8
# 12
# 16
# 20
# 24
# 28
# 32
# 36
# 40
# 44
# 48
# 52
# 56
# 60
# 64
# 68
# 72
# 76
# 80
# 84
# 88
# 92
# 96
# 100

# %%
# for loop with list 

l = [1,4,6,234,6,764]

for i in l:
    print(i)
# Out:
# 1
# 4
# 6
# 234
# 6
# 764

# %%
# for loop with tuples 

t = (6,231,75,122,23)

for i in t :
    print(i)
# Out:
# 6
# 231
# 75
# 122
# 23

# %%
# for loop with strings

s = "aaradhya"

for item in s :
    print(item)
# Out:
# a
# a
# r
# a
# d
# h
# y
# a
