# %% [markdown]
# write a program to print multiplication table of a given number using "for loop" .

# %%
n = int(input("enter a number : "))

for i in range(1,11):
    print(f"{n} X {i} = {n * i}")
# Out:
# 9 X 1 = 9
# 9 X 2 = 18
# 9 X 3 = 27
# 9 X 4 = 36
# 9 X 5 = 45
# 9 X 6 = 54
# 9 X 7 = 63
# 9 X 8 = 72
# 9 X 9 = 81
# 9 X 10 = 90

# %% [markdown]
# write a program to greet all the person names stored in a list "l" and starts with 's' .
#
#     l = ["Harry" , "Soham" , "Sachin" , "Rahul"]

# %%
l = ["Harry" , "Soham" , "Sachin" , "Rahul"]

for name in l: 
    if(name.startswith("S")):
        print(f"hello {name}")
# Out:
# hello Soham
# hello Sachin

# %% [markdown]
# attempt problem 1 using while loop
#
# problem 1
# write a program to print multiplication table of a given number using "for loop" .

# %%
n = int(input("enter a number : "))

i= 1
while (i<11):
    print(f"{n} X {i} = {n * i}")
    i+=1
# Out:
# 4 X 1 = 4
# 4 X 2 = 8
# 4 X 3 = 12
# 4 X 4 = 16
# 4 X 5 = 20
# 4 X 6 = 24
# 4 X 7 = 28
# 4 X 8 = 32
# 4 X 9 = 36
# 4 X 10 = 40

# %% [markdown]
# write a program to find whether a given number is prime or not.

# %%
n = int(input("enter a number : "))

for i in range(2,n):

    if(n%i) == 0:
        print("number is not a prime number")

    else :
        print("number is a prime number")
    break
# Out:
# number is not a prime number

# %% [markdown]
# write a program to find the sum of first "n" natural numbers using while loop.

# %%
n = int(input("enter a number"))

i = 1
sum = 0

while(i<=n):
    sum+=i
    i+=1

print(sum)
# Out:
# 6

# %% [markdown]
# write a program to calculate the factorial of a given number using for loop .

# %%
# 5! = 1 X 2 X 3 X 4 X 5
n = int(input("enter a number: "))

product = 1

for i in range(1 , n+1):
    product = product * i

print(f"the factorial of {n} is {product}")
# Out:
# the factorial of 10 is 3628800

# %% [markdown]
# write a program to print the following star patern.
#
#   *
#  ***
# *****
# for n = 3

# %%
n =  int(input("enter a number : "))

for i in range(1 , n+1):

    print(" " * (n-i) , end=" ")
    print ("*" * (2*i-1) , end=" ")

    print(" ")
# Out:
#      *
#     ***
#    *****
#   *******
#  *********

# %% [markdown]
# write a program to print the following star pattern :
#
# *
# **
# ***
# for n = 3

# %%
n =  int(input("enter a number : "))

for i in range(1,n+1):
    
    print("*" * (i) , end="")
    
    print("")
# Out:
# *
# **
# ***
# ****
# *****

# %% [markdown]
# write a program to print the following star pattern .
#
# * * *
# *   *
# * * *
# for n = 3

# %%
n = int(input("enter a number : "))

for i in range(1,n+1):

    if (i==1 or i==n):
        print("*" * n , end=" ")

    else:
        print("*" , end="")
        print(" " * (n-2) , end="")
        print("*" , end="")

    print("")
# Out:
# **********
# *        *
# *        *
# *        *
# *        *
# *        *
# *        *
# *        *
# *        *
# **********

# %% [markdown]
# write a program to print multiplication table of n using "for loops" in reversed order

# %%
n = int(input("enter a number : "))


for i in range(1,11):
    print(f"{n} X {11-i} = {n*(11-i)}")
# Out:
# 5 X 10 = 50
# 5 X 9 = 45
# 5 X 8 = 40
# 5 X 7 = 35
# 5 X 6 = 30
# 5 X 5 = 25
# 5 X 4 = 20
# 5 X 3 = 15
# 5 X 2 = 10
# 5 X 1 = 5
