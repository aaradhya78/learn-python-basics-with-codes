# %%
# dictionary 
marks = {
    "harry" : 80,
    "raju": 39,
    "rohan": 60,
    "list":[1,2,3]
}

print(marks, type(marks))

print (marks["harry"])

print(marks["list"])
# Out:
# {'harry': 80, 'raju': 39, 'rohan': 60, 'list': [1, 2, 3]} <class 'dict'>
# 80
# [1, 2, 3]
# 80
