# %%
s= set() 
#this is a empty set
# don't use set{}, it will create a empty dictionary 
print(type(s))
# Out:
# <class 'set'>

# %%
s={1,5,32,54,5,5,5}
print(s)

# this shows that sets are unordered
# Out:
# {32, 1, 5, 54}
