# %%
a=(1,2,5,6)

print(type(a))
# Out:
# <class 'tuple'>

# %%
# empty tuple

a=()
print(type(a))
# Out:
# <class 'tuple'>

# %%
# tuple with only one element need a coma 

a=(1, )
print(type(a))
# Out:
# <class 'tuple'>

# %%
# tuple with more than one element

a=(1,7,2)
print(type(a))
# Out:
# <class 'tuple'>
