# %%
# lists 
# lists are mutable , means we can change any character in the list
 
friends=["apple","orange",7,9.19,False,"akash","rohan"]

print(friends)

friends[0]="grapes"

print(friends)
# Out:
# ['apple', 'orange', 7, 9.19, False, 'akash', 'rohan']
# ['grapes', 'orange', 7, 9.19, False, 'akash', 'rohan']
